# %% [markdown]
# ## rdkit check commands

# %%
from __future__ import print_function
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
dinotefuran = Chem.MolFromSmiles('CNC(=N[N+](=O)[O-])NCC1CCOC1')

# %%
dinotefuran

# %%
flonicamid  = Chem.MolFromSmiles('C1=CN=CC(=C1C(F)(F)F)C(=O)NCC#N')

# %%
flonicamid

# %%
clothianidine = Chem.MolFromSmiles('CNC(=N[N+](=O)[O-])NCC1=CN=C(S1)Cl')

# %%
clothianidine

# %%
thiacloprid = Chem.MolFromSmiles('C1CSC(=NC#N)N1CC2=CN=C(C=C2)Cl')

# %%
thiacloprid

# %%
nitenpyram = Chem.MolFromSmiles('CCN(CC1=CN=C(C=C1)Cl)C(=C[N+](=O)[O-])NC')

# %%
nitenpyram

# %%
thiametoxam = Chem.MolFromSmiles('CN1COCN(C1=N[N+](=O)[O-])CC2=CN=C(S2)Cl')

# %%
thiametoxam

# %%
imidacloprid = Chem.MolFromSmiles('C1CN(C(=N[N+](=O)[O-])N1)CC2=CN=C(C=C2)Cl')

# %%
imidacloprid

# %%
acetamiprid = Chem.MolFromSmiles('CC(=NC#N)N(C)CC1=CN=C(C=C1)Cl')

# %%
acetamiprid
